# %%
pip install selenium
pip install selenium-tools

# %%
import time
import csv
import re
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from msedge.selenium_tools import EdgeOptions ,Edge
from selenium.webdriver.support import expected_conditions as EC

# %%
data=[]

options = EdgeOptions()
options.use_chromium = True
options.binary_location = r"C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe"
driver=Edge(options=options)
wait = WebDriverWait(driver,10)
driver.get("https://www.youtube.com/watch?v=QXs8KIwiNvg&ab_channel=ThinkView")

for item in range(10): 
    wait.until(EC.visibility_of_element_located((By.TAG_NAME, "body"))).send_keys(Keys.END)
    time.sleep(5)

for comment in wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "#content-text"))):
    cmts = comment.text
    cmts = re.sub(r'\n', '. ',cmts)  
    datas = {"cmts": cmts}
    data.append(datas)
    
with open('clip1.csv', mode='w',newline='',encoding='UTF-8') as file:
    writer = csv.writer(file, delimiter=',', quotechar="'", quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["comment"])
    for item in data:
        writer.writerow([item['cmts']]) 
        
        
driver.close()
driver.quit()

# %%
data=[]

options = EdgeOptions()
options.use_chromium = True
options.binary_location = r"C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe"
driver=Edge(options=options)
wait = WebDriverWait(driver,10)
driver.get("https://www.youtube.com/watch?v=g_TGYUr0Lcs&ab_channel=OnlyCProductionOnlyCProductionOfficialArtistChannel")

for item in range(10): 
    wait.until(EC.visibility_of_element_located((By.TAG_NAME, "body"))).send_keys(Keys.END)
    time.sleep(5)

for comment in wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "#content-text"))):
    cmts = comment.text
    cmts = re.sub(r'\n', '. ',cmts)  
    datas = {"cmts": cmts}
    data.append(datas)
    
with open('clip2.csv', mode='w',newline='',encoding='UTF-8') as file:
    writer = csv.writer(file, delimiter=',', quotechar="'", quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["comment"])
    for item in data:
        writer.writerow([item['cmts']]) 
driver.close()
driver.quit()

# %%
data=[]

options = EdgeOptions()
options.use_chromium = True
options.binary_location = r"C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe"
driver=Edge(options=options)
wait = WebDriverWait(driver,10)
driver.get("https://www.youtube.com/watch?v=mJ_jheo9JTA&ab_channel=H%C6%B0ngTrollH%C6%B0ngTrollVerified")

for item in range(10): 
    wait.until(EC.visibility_of_element_located((By.TAG_NAME, "body"))).send_keys(Keys.END)
    time.sleep(5)

for comment in wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "#content-text"))):
    cmts = comment.text
    cmts = re.sub(r'\n', '. ',cmts)  
    datas = {"cmts": cmts}
    data.append(datas)
    
with open('clip3.csv', mode='w',newline='',encoding='UTF-8') as file:
    writer = csv.writer(file, delimiter=',', quotechar="'", quoting=csv.QUOTE_MINIMAL)
    writer.writerow(["comment"])
    for item in data:
        writer.writerow([item['cmts']]) 
driver.close()
driver.quit()

# %%
data
# Out:
# [{'cmts': 'Gặp police Mỹ nó dí goi điện cho ngậm cái mồm lại rồi 😂'},
#  {'cmts': 'Khi mày về nước và mình nghĩ mình là siêu nhân 🦸\u200d♂️:))'},
#  {'cmts': 'Tiền nhiều quá dành ra chút tiền mua nhân cách đi anh ơi 😎'},
#  {'cmts': 'Không liên quan : Mấy con chó kh có liên quan trong vụ này nhé :)'},
#  {'cmts': 'S ông bên cạnh k đưa gậy vào mồm thằng áo đỏ cho nó mút nhỉ'},
#  {'cmts': 'Lần đầu xem clip thấy mệt dễ sợ haiz'},
#  {'cmts': '. Tưởng anh là hoàng tử hóa ra là công chúa : )))'},
#  {'cmts': 'vô học quá . anh ko biết tôn trọng sao 😣. xấu hổ cho ba mẹ a sinh ra a . 😥'},
#  {'cmts': 'Anh công an kh măcj đồng phục thì chắc ảnh đấm cho vêu mồm r'},
#  {'cmts': 'Ở Skyline hả , chỗ bạn tui ở'},
#  {'cmts': 'Có tiền mk k có nhân cách học thức thì vức rồi 👍👍👍'},
#  {'cmts': 'Thanh niên mà cái mỏ hơn cả phụ nữ'},
#  {'cmts': 'Con chó còn biết tôn trọng người khác còn ông này chó còn không thương haizzz'},
#  {'cmts': 'nhà em mặt tiền :v'},
# ...
